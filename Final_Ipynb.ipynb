# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
print(tf.__version__)

# Create a list with the filepaths for training and testing
train_dir = Path('../input/fruit-and-vegetable-image-recognition/train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))
test_dir = Path('../input/fruit-and-vegetable-image-recognition/test')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))
val_dir = Path('../input/fruit-and-vegetable-image-recognition/validation')
val_filepaths = list(test_dir.glob(r'**/*.jpg'))


def image_processing(filepath):
     """ Create a DataFrame with the filepath and the labels of the pictures
     """

     labels = [str(filepath[i]).split("/")[-2] \
               for i in range(len(filepath))]

     filepath = pd.Series(filepath, name='Filepath').astype(str)
     labels = pd.Series(labels, name='Label')

     # Concatenate filepaths and labels
     df = pd.concat([filepath, labels], axis=1)

     # Shuffle the DataFrame and reset index
     df = df.sample(frac=1).reset_index(drop=True)

     return df


train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')

train_df.head(5)

# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False

inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(36, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)

# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)
# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred1 = [labels[k] for k in pred]
pred1

def output(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict(img)
    y_class = answer.argmax(axis=-1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = labels[y]
    return res
img = output('../input/fruit-and-vegetable-image-recognition/test/cabbage/Image_1.jpg')
img

model.save('FV.h5')
# Out:
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/capsicum/Image_3.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/validation
Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/sweetpotato/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/sweetpotato/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/sweetpotato/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_7.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/grapes/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/cucumber/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/corn/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/banana/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/garlic/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_2.png
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_5.png
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/chilli pepper/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/watermelon/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/mango/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_6.png
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/peas/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_7.png
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/onion/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_5.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/potato/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/spinach/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/validation/soy beans/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_3.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/capsicum/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/sweetcorn/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_1.png
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_10.png
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_8.jpeg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/orange/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/tomato/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/turnip/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/ginger/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_5.png
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_9.jpeg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/raddish/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/pomegranate/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/pomegranate/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/pomegranate/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/pomegranate/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/test/
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_98.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_21.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_63.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_95.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_93.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_25.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_17.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_96.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_15.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_54.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_13.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_89.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_43.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_40.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_91.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_97.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_55.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_78.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_49.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_35.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_42.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_84.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_38.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_46.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_80.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_100.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_68.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_20.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_24.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_73.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_76.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_29.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_57.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_37.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_71.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/train/spinach/Image_82.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_22.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_69.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_68.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_13.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_51.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_88.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_4.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_75.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_12.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_16.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_72.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_58.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_62.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_2.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_45.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_7.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_85.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_65.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_5.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_86.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_99.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_36.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_18.JPG
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_33.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_19.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_31.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_27.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_66.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_61.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_92.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_11.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_39.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_74.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_79.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_26.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_28.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_44.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_14.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_48.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_41.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_10.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_81.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_47.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_30.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_77.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_59.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_23.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_60.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_63.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_94.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_50.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_70.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_83.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_32.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_98.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_21.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_95.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_93.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_25.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_17.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_87.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_15.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_42.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_54.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_90.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_1.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_89.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_43.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_40.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_91.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_97.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_34.png
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_56.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_55.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_78.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_35.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_80.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_8.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_84.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_38.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_67.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_46.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_49.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_3.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_100.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_20.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_64.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_52.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_24.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_73.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_76.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_29.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_57.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_37.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_6.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_9.jpg
# /kaggle/input/fruit-and-vegetable-image-recognition/train/soy beans/Image_71.jpg
# 2.6.4
# -- Training set --
#
# Number of pictures: 2780
#
# Number of different labels: 36
#
# Labels: ['onion' 'potato' 'soy beans' 'paprika' 'corn' 'pear' 'peas' 'cauliflower'
#  'pineapple' 'lettuce' 'ginger' 'raddish' 'tomato' 'beetroot' 'kiwi'
#  'cucumber' 'bell pepper' 'apple' 'mango' 'carrot' 'garlic' 'grapes'
#  'chilli pepper' 'orange' 'spinach' 'sweetcorn' 'jalepeno' 'lemon'
#  'capsicum' 'banana' 'watermelon' 'sweetpotato' 'turnip' 'cabbage'
#  'eggplant' 'pomegranate']
# Found 2780 validated image filenames belonging to 36 classes.
# Found 334 validated image filenames belonging to 36 classes.
# Found 334 validated image filenames belonging to 36 classes.
# 2022-11-08 04:20:36.987257: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# 2022-11-08 04:20:39.800431: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/5
# 87/87 [==============================] - 178s 2s/step - loss: 1.6429 - accuracy: 0.5662 - val_loss: 0.4431 - val_accuracy: 0.8503
# Epoch 2/5
# 87/87 [==============================] - 132s 2s/step - loss: 0.5446 - accuracy: 0.8266 - val_loss: 0.2953 - val_accuracy: 0.9012
# Epoch 3/5
# 87/87 [==============================] - 132s 2s/step - loss: 0.3254 - accuracy: 0.8982 - val_loss: 0.1944 - val_accuracy: 0.9491
# Epoch 4/5
# 87/87 [==============================] - 133s 2s/step - loss: 0.2125 - accuracy: 0.9331 - val_loss: 0.1892 - val_accuracy: 0.9401
# Epoch 5/5
# 87/87 [==============================] - 131s 2s/step - loss: 0.1406 - accuracy: 0.9561 - val_loss: 0.1650 - val_accuracy: 0.9521
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
